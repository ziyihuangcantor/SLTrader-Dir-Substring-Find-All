# %%
import os

# %%
# Finds all .cshtml files that containing the target string

path = 'C:/Users/ZH128895/Work/SLTraderDirSubstringFindAll/Areas'

target_str = '@html.text'.lower()

target_files = []

for root, dirs, files in os.walk(path):
    for file in files:
        if(file.endswith('.cshtml')):
            with open(os.path.join(root, file), 'r') as f:
                content = f.read()
                if target_str in str(content).lower():
                    # Gets the full path
                    my_dir = str(os.path.join(root,file))
                    
                    # Clean up the path
                    my_dir_trunc = my_dir.replace('C:/Users/ZH128895/Work/SLTraderDirSubstringFindAll/', '~')
                    target_dir = my_dir_trunc.replace('\\', '/')
                    
                    inner_dict = {}
                    inner_dict[target_dir] = []
                    
                    
                    with open(os.path.join(root, file), 'r') as f2:
                        lines = f2.readlines()
                        count = 0
                        for line in lines:
                            count = count + 1
                            if target_str in str(line).lower():
                                inner_dict[target_dir].append(str(count))
                                
                    target_files.append(inner_dict)
# Out:
# 34
# 38
# 45
# 49
# 54
# 56
# 60
# 62
# 66
# 68
# 72
# 74
# 78
# 80
# 84
# 86
# 90
# 92
# 102
# 108
# 110
#
#
# 32
#
#
# 59
#
#
# 557
# 575
# 584
# 593
#
#
# 150
# 158
# 164
# 174
# 176
# 180
#
#
# 161
# 169
# 175
# 185
# 187
# 191
#
#
# 461
#
#
# 446
# 508
#
#
# 271
# 309
# 323
# 329
# 335
#
#
# 68
#
#
# 111
# 113
# 117
# 119
# 125
#
#
# 115
# 121
# 126
#
#
# 60
# 62
# 66
# 68
#
#
# 8
# 12
# 16
# 20
# 24
# 28
# 32
# 36
# 40
# 52
# 56
#
#
# 3
#
#
# 826
#
#
# 970
#
#
# 1444
# 1842
#
#
# 119
# 125
# 131
# 155
# 159
# 170
# 174
# 187
# 291
# 295
# 302
# 306
# 315
# 319
# 326
# 330
#
#
# 56
#
#
# 38
#
#
# 11
# 19
# 25
# 33
# 39
# 53
# 64
# 70
#
#
# 1846
#
#
# 323
#
#
# 109
#
#
# 111
#
#
# 54
# 58
# 65
# 69
#
#
# 9
#
#
# 58
#
#
# 141
# 149
# 157
#
#
# 100

# %%
target_files
# Out:
# ['~Areas/Admin/Views/Shared/Templates/_Company.cshtml',
#  '~Areas/Admin/Views/Shared/Templates/_UserRoleType.cshtml',
#  '~Areas/Dashboard/Views/Research/_ResearchByIssue.cshtml',
#  '~Areas/DomesticTrading/Views/AutoAction/_AutoBorrow.cshtml',
#  '~Areas/DomesticTrading/Views/AutoAction/_AutoBorrowDefaultOptions.cshtml',
#  '~Areas/DomesticTrading/Views/AutoBorrow/_AutoBorrowDefaultOptions.cshtml',
#  '~Areas/DomesticTrading/Views/AutoBorrow/_AutoBorrowHelper.cshtml',
#  '~Areas/DomesticTrading/Views/AutoBorrow/_AutoBorrowScratchpad.cshtml',
#  '~Areas/DomesticTrading/Views/AutoBorrow/_UpdateAutoBorrows.cshtml',
#  '~Areas/DomesticTrading/Views/AutoLoan/_AutoLoanBulkRateChange.cshtml',
#  '~Areas/DomesticTrading/Views/AutoLoan/_AutoLoanDefaultOptions.cshtml',
#  '~Areas/DomesticTrading/Views/ClientNeed/_AddClientNeed.cshtml',
#  '~Areas/DomesticTrading/Views/FPLending/_FPLendingDefaultOptions.cshtml',
#  '~Areas/DomesticTrading/Views/Shared/_RecallUpdate.cshtml',
#  '~Areas/DomesticTrading/Views/Shared/Editor Templates/String.cshtml',
#  '~Areas/DomesticTrading/Views/Shared/Templates/_BoxCalculationBulkRateChanges.cshtml',
#  '~Areas/DomesticTrading/Views/Shared/Templates/_BoxCalculationBulkReturn.cshtml',
#  '~Areas/DomesticTrading/Views/Shared/Templates/_BoxCalculationTrade.cshtml',
#  '~Areas/DomesticTrading/Views/Shared/Templates/_ContraEntityDetail.cshtml',
#  '~Areas/DomesticTrading/Views/Shared/Templates/_ContraEntityParentDetail.cshtml',
#  '~Areas/DomesticTrading/Views/Shared/Templates/_ErrorMessage.cshtml',
#  '~Areas/DomesticTrading/Views/Shared/Templates/_RecallUpdate.cshtml',
#  '~Areas/DomesticTrading/Views/Trade/_Scratchpad.cshtml',
#  '~Areas/DomesticTrading/Views/Trade/_UpdateTradesBreakOut.cshtml',
#  '~Areas/Locates/Views/Inventory/Index.cshtml',
#  '~Areas/Locates/Views/Locates/_InventoryList.cshtml',
#  '~Areas/Locates/Views/Shared/Templates/_LocateClient.cshtml',
#  '~Areas/Login/Views/Login_backup/_Login.cshtml',
#  '~Areas/Monitor/Views/Shared/_SecurityMaster.cshtml',
#  '~Areas/RebateBilling/Views/Groups/_AddIssueOverride.cshtml',
#  '~Areas/RebateBilling/Views/RebateBilling/_RebateBillingDefaultOptions.cshtml']
